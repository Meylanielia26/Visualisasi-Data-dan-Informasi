# %% [markdown]
# 1. Tujuan
#
# a. Menganalisis hubungan antar fitur bunga Iris: Tujuan utama visualisasi ini adalah untuk melihat bagaimana fitur-fitur dalam dataset Iris, seperti panjang dan lebar sepal dan petal, berhubungan satu sama lain berdasarkan spesies yang berbeda.
#
# b. Mengidentifikasi pola: Pola atau tren yang berbeda di antara tiga spesies Iris (setosa, versicolor, dan virginica) dapat diidentifikasi dengan menggunakan visualisasi seperti scatter plot, box plot, dan pair plot.
#
# c. Membantu dalam klasifikasi: Visualisasi ini dapat digunakan untuk menemukan fitur yang paling penting untuk membedakan spesies yang berbeda, yang berguna untuk model klasifikasi dalam pembelajaran mesin.
#
# 2. User
#
# a. Peneliti,
#
# b. Pengajar/Pembelajar dalam bidang machine learning, dan
#
# c. Pengambil Keputusan.
#
# 3. Fungsi
#
# a. Exploratory Data Analysis (EDA): Fungsi utama visualisasi ini adalah sebagai alat eksplorasi data yang memungkinkan
# pemahaman tentang struktur dataset dan hubungan antar fitur.
#
# b. Klasifikasi Data: Ini merupakan bagian penting dari pengembangan model pembelajaran mesin karena membantu dalam menentukan fitur yang dapat digunakan untuk membedakan spesies bunga Iris.
#
# c. Penyajian Data Secara Visual: Membuat data lebih mudah dipahami dan membantu dalam pengambilan keputusan atau analisis.
#
# 4. Tone (Nada)
#
# a. Informal tetapi Informatif: Visualisasi ini bertujuan untuk menyampaikan informasi dengan cara yang sederhana dan tidak terlalu formal, sehingga mudah dipahami. Tujuannya adalah untuk memberikan wawasan yang mendalam tetapi mudah dipahami bagi pemula atau orang yang baru mengenal data ini.
#
# b. Fokus pada Kejelasan: Nada visualisasi ini berfokus pada kejelasan dan kemudahan interpretasi data, tanpa terlalu banyak elemen dekoratif yang dapat mengganggu fokus analisis.

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Hiko\\OneDrive\\Dokumen\\VDI\\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df. isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
pip install seaborn matplotlib pandas
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='PetalLengthCm', y='PetalWidthCm', hue='Species', palette='Set1', s=100)
plt.title('Petal Length vs Petal Width by Iris Species', fontsize=16)
plt.xlabel('Petal Length (cm)', fontsize=12)
plt.ylabel('Petal Width (cm)', fontsize=12)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Species', y='PetalLengthCm', data=df, palette='Set2')
plt.title('Distribution of Petal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Length (cm)', fontsize=12)
plt.show()
# Out:
# C:\Users\Hiko\AppData\Local\Temp\ipykernel_19976\545896430.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y='PetalLengthCm', data=df, palette='Set2')

# %%
sns.pairplot(df, hue="Species", palette="Set1", diag_kind="kde", markers=["o", "s", "D"])
plt.suptitle('Pair Plot of Iris Dataset', y=1.02, fontsize=16)
plt.show()
